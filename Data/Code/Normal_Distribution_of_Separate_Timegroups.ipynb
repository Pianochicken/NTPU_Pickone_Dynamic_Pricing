# %%
import os
import codecs
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
cd drive/My\ Drive/Programmation\ Data/
# Out:
# /content/drive/My Drive/Programmation Data

# %%
ls
# Out:
#  Fake_Orders_in_Empty_Time.csv         Real_Order.csv
#  Fake_Orders_in_Real_Orders_Time.csv  'space_device (Tranfer).csv'
# 'Final Fake & Real Orders.csv'         Space_info.csv
#  god_account_view.csv                  spaces.csv
# 'Old Data'/                            spaces_devices.csv
#  old_new_order_original.csv            spaces_first_time_upload.csv
#  old_new_order_origional2.csv          spaces_times.csv
#  orders.csv

# %%
import numpy as np
import pandas as pd

### data_space_sort 資料表按照space_id排序
data_space_sort = pd.read_csv("Real_Order.csv", encoding = 'utf-8')
data_space_sort
# Out:
#            id  locate_id  space_id  size  hours  price  ...  14  15 16 17 18 19
# 0       10403          8         1    12    4.0    300  ...   0   0  1  1  1  1
# 1       10286          8         1    12    3.0    300  ...   0   0  1  1  1  1
# 2        9949          8         1    12    3.0    300  ...   0   0  1  1  1  1
# 3       10285          8         1    12    3.0    300  ...   0   0  1  1  1  1
# 4        9950          8         1    12    2.0    300  ...   0   0  1  1  1  1
# ...       ...        ...       ...   ...    ...    ...  ...  ..  .. .. .. .. ..
# 96049  194525         22       187    22    8.0    700  ...   0   0  1  0  1  1
# 96050  194396         22       187    22    4.0    700  ...   0   0  1  0  1  1
# 96051  195657         22       187    22    2.0    700  ...   0   0  1  0  1  1
# 96052  194531         22       187    22    8.0    700  ...   0   0  1  0  1  1
# 96053  193859         22       187    22    4.0    700  ...   0   0  1  0  1  1
#
# ...

# %%
###偵測資料數目
number_of_data = len(data_space_sort['space_id'])
print("資料筆數: ", number_of_data)
# Out:
# 資料筆數:  96054

# %% [markdown]
# #宣告space_sort資料表的資料結構

# %%
space_id = np.array(data_space_sort['space_id'])
weekday = np.array(data_space_sort['weekday'])
start_time_group = np.array(data_space_sort['start_time_group'])
end_time_group = np.array(data_space_sort['end_time_group'])
create_data_space = np.array(data_space_sort['created_at'])
actual_date_space = np.array(data_space_sort['date'])
actual_time_space = np.array(data_space_sort['start'])

# %%
###將create日期與時間合併
actual_data_space = np.array(actual_date_space + ' ' + actual_time_space)
actual_data_space
# Out:
# array(['1/8/2017 13:00', '20/6/2017 19:30', '27/2/2017 18:30', ...,
#        '23/12/2019 19:00', '21/12/2019 9:30', '14/12/2019 12:00'],
#       dtype=object)

# %%
###宣告各個群組lead_time陣列
lead_time_space_weekday1_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday1_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday1_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday1_group4 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday2_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday2_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday2_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday2_group4 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday3_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday3_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday3_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday3_group4 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday4_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday4_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday4_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday4_group4 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday5_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday5_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday5_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday5_group4 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday6_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday6_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday6_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday6_group4 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday7_group1 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday7_group2 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday7_group3 = np.zeros(number_of_data,dtype = float)
lead_time_space_weekday7_group4 = np.zeros(number_of_data,dtype = float)

###宣告計數器
counter1_1 = 0
counter1_2 = 0
counter1_3 = 0
counter1_4 = 0
counter2_1 = 0
counter2_2 = 0
counter2_3 = 0
counter2_4 = 0
counter3_1 = 0
counter3_2 = 0
counter3_3 = 0
counter3_4 = 0
counter4_1 = 0
counter4_2 = 0
counter4_3 = 0
counter4_4 = 0
counter5_1 = 0
counter5_2 = 0
counter5_3 = 0
counter5_4 = 0
counter6_1 = 0
counter6_2 = 0
counter6_3 = 0
counter6_4 = 0
counter7_1 = 0
counter7_2 = 0
counter7_3 = 0
counter7_4 = 0

######宣告函式
### 接收weekday,start_group,end_group以分開計算
def group_linear(weekday,x,y):   
  if(weekday == 1):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday1(x)
      x += 1
  elif(weekday == 2):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday2(x)
      x += 1
  elif(weekday == 3):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday3(x)
      x += 1
  elif(weekday == 4):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday4(x)
      x += 1
  elif(weekday == 5):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday5(x)
      x += 1
  elif(weekday == 6):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday6(x)
      x += 1
  elif(weekday == 7):
    a = y-x
    for i in range(0,a+1):
      call = x
      group_select_weekday7(x)
      x += 1

### weekday1閘道函式
def group_select_weekday1(x):
  global b1, b2, b3, b4,counter1_1,counter1_2,counter1_3,counter1_4
  if(x == 1):
    lead_time_space_weekday1_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter1_1 += 1
  elif(x == 2):
    lead_time_space_weekday1_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter1_2 += 1
  elif(x == 3):
    lead_time_space_weekday1_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter1_3 += 1
  elif(x == 4):
    lead_time_space_weekday1_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter1_4 += 1

def group_select_weekday2(x):
  global b1, b2, b3, b4,counter2_1,counter2_2,counter2_3,counter2_4
  if(x == 1):
    lead_time_space_weekday2_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter2_1 += 1
  elif(x == 2):
    lead_time_space_weekday2_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter2_2 += 1
  elif(x == 3):
    lead_time_space_weekday2_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter2_3 += 1
  elif(x == 4):
    lead_time_space_weekday2_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter2_4 += 1

def group_select_weekday3(x):
  global b1, b2, b3, b4,counter3_1,counter3_2,counter3_3,counter3_4
  if(x == 1):
    lead_time_space_weekday3_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter3_1 += 1
  elif(x == 2):
    lead_time_space_weekday3_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter3_2 += 1
  elif(x == 3):
    lead_time_space_weekday3_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter3_3 += 1
  elif(x == 4):
    lead_time_space_weekday3_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter3_4 += 1

def group_select_weekday4(x):
  global b1, b2, b3, b4,counter4_1,counter4_2,counter4_3,counter4_4
  if(x == 1):
    lead_time_space_weekday4_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter4_1 += 1
  elif(x == 2):
    lead_time_space_weekday4_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter4_2 += 1
  elif(x == 3):
    lead_time_space_weekday4_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter4_3 += 1
  elif(x == 4):
    lead_time_space_weekday4_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter4_4 += 1

def group_select_weekday5(x):
  global b1, b2, b3, b4,counter5_1,counter5_2,counter5_3,counter5_4
  if(x == 1):
    lead_time_space_weekday5_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter5_1 += 1
  elif(x == 2):
    lead_time_space_weekday5_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter5_2 += 1
  elif(x == 3):
    lead_time_space_weekday5_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter5_3 += 1
  elif(x == 4):
    lead_time_space_weekday5_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter5_4 += 1

def group_select_weekday6(x):
  global b1, b2, b3, b4,counter6_1,counter6_2,counter6_3,counter6_4
  if(x == 1):
    lead_time_space_weekday6_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter6_1 += 1
  elif(x == 2):
    lead_time_space_weekday6_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter6_2 += 1
  elif(x == 3):
    lead_time_space_weekday6_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter6_3 += 1
  elif(x == 4):
    lead_time_space_weekday6_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter6_4 += 1

def group_select_weekday7(x):
  global b1, b2, b3, b4,counter7_1,counter7_2,counter7_3,counter7_4
  if(x == 1):
    lead_time_space_weekday7_group1[b1] = time.total_seconds()/3600
    b1 += 1
    counter7_1 += 1
  elif(x == 2):
    lead_time_space_weekday7_group2[b2] = time.total_seconds()/3600
    b2 += 1
    counter7_2 += 1
  elif(x == 3):
    lead_time_space_weekday7_group3[b3] = time.total_seconds()/3600
    b3 += 1
    counter7_3 += 1
  elif(x == 4):
    lead_time_space_weekday7_group4[b4] = time.total_seconds()/3600
    b4 += 1
    counter7_4 += 1

######將訂單分群並存到相對應的陣列
###main function
import datetime
import math

a = 0   #紀錄每筆order
b1 = 0 
b2 = 0
b3 = 0
b4 = 0

space_number = space_id[number_of_data-1]-3   #只算到space_id(184)
          ##################### Weekday1 #####################
a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 

    if(weekday[a] == 1):
      weekday_number = 1
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
    
      if(a == number_of_data):break
    else:
      a += 1
      
  else:continue
  if(a == number_of_data):break

          ##################### Weekday2 #####################

a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 
    if(weekday[a] == 2):
      weekday_number = 2
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
    
      if(a == number_of_data):break
    else:
      a += 1

  else:continue   
  if(a == number_of_data):break

##################### Weekday3 #####################

a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 
    if(weekday[a] == 3):
      weekday_number = 3
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
      if(a == number_of_data):break
    else:
      a += 1
      
  else:continue
  if(a == number_of_data):break

##################### Weekday4 #####################

a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 
    if(weekday[a] == 4):
      weekday_number = 4
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
      if(a == number_of_data):break
    else:
      a += 1
  else:continue
  if(a == number_of_data):break

##################### Weekday5 #####################

a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 
    if(weekday[a] == 5):
      weekday_number = 5
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
      if(a == number_of_data):break
    else:
      a += 1
      
  else:continue
  if(a == number_of_data):break

##################### Weekday6 #####################

a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 
    if(weekday[a] == 6):
      weekday_number = 6
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
      if(a == number_of_data):break
    else:
      a += 1
      
  else:continue
  if(a == number_of_data):break

##################### Weekday7 #####################

a = 0
b1 = 0 
b2 = 0
b3 = 0
b4 = 0
x = 0
y = 0
weekday_number = 0
for i in range(1,space_number+1):
  while (space_id[a] == i): 
    if(weekday[a] == 7):
      weekday_number = 7
      date1 = actual_data_space[a]
      date2 = create_data_space[a]
      start = datetime.datetime.strptime(date2, '%d/%m/%Y %H:%M:%S')
      end = datetime.datetime.strptime(date1, '%d/%m/%Y %H:%M')
      time = end - start
      x = int(start_time_group[a])
      y = int(end_time_group[a])
      group_linear(weekday_number,x,y)  
      a += 1
      if(a == number_of_data):break
    else:
      a += 1
      
  else:continue
  if(a == number_of_data):break

# %%
###宣告個時段lead_time平均值
mean1_1 = 0
mean1_2 = 0
mean1_3 = 0
mean1_4 = 0
mean2_1 = 0
mean2_2 = 0
mean2_3 = 0
mean2_4 = 0
mean3_1 = 0
mean3_2 = 0
mean3_3 = 0
mean3_4 = 0
mean4_1 = 0
mean4_2 = 0
mean4_3 = 0
mean4_4 = 0
mean5_1 = 0
mean5_2 = 0
mean5_3 = 0
mean5_4 = 0
mean6_1 = 0
mean6_2 = 0
mean6_3 = 0
mean6_4 = 0
mean7_1 = 0
mean7_2 = 0
mean7_3 = 0
mean7_4 = 0

###計算mean
total = 0
for i in range (0,counter1_1):
  total += lead_time_space_weekday1_group1[i]
mean1_1 = total/counter1_1
total = 0
for i in range (0,counter1_2):
  total += lead_time_space_weekday1_group2[i]
mean1_2 = total/counter1_2
total = 0
for i in range (0,counter1_3):
  total += lead_time_space_weekday1_group3[i]
mean1_3 = total/counter1_3
total = 0
for i in range (0,counter1_4):
  total += lead_time_space_weekday1_group4[i]
mean1_4 = total/counter1_4
total = 0
for i in range (0,counter2_1):
  total += lead_time_space_weekday2_group1[i]
mean2_1 = total/counter2_1
total = 0
for i in range (0,counter2_2):
  total += lead_time_space_weekday2_group2[i]
mean2_2 = total/counter2_2
total = 0
for i in range (0,counter2_3):
  total += lead_time_space_weekday2_group3[i]
mean2_3 = total/counter2_3
total = 0
for i in range (0,counter2_4):
  total += lead_time_space_weekday2_group4[i]
mean2_4 = total/counter2_4
total = 0
for i in range (0,counter3_1):
  total += lead_time_space_weekday3_group1[i]
mean3_1 = total/counter3_1
total = 0
for i in range (0,counter3_2):
  total += lead_time_space_weekday3_group2[i]
mean3_2 = total/counter3_2
total = 0
for i in range (0,counter3_3):
  total += lead_time_space_weekday3_group3[i]
mean3_3 = total/counter3_3
total = 0
for i in range (0,counter3_4):
  total += lead_time_space_weekday3_group4[i]
mean3_4 = total/counter3_4
total = 0
for i in range (0,counter4_1):
  total += lead_time_space_weekday4_group1[i]
mean4_1 = total/counter4_1
total = 0
for i in range (0,counter4_2):
  total += lead_time_space_weekday4_group2[i]
mean4_2 = total/counter4_2
total = 0
for i in range (0,counter4_3):
  total += lead_time_space_weekday4_group3[i]
mean4_3 = total/counter4_3
total = 0
for i in range (0,counter4_4):
  total += lead_time_space_weekday4_group4[i]
mean4_4 = total/counter4_4
total = 0
for i in range (0,counter5_1):
  total += lead_time_space_weekday5_group1[i]
mean5_1 = total/counter5_1
total = 0
for i in range (0,counter5_2):
  total += lead_time_space_weekday5_group2[i]
mean5_2 = total/counter5_2
total = 0
for i in range (0,counter5_3):
  total += lead_time_space_weekday5_group3[i]
mean5_3 = total/counter5_3
total = 0
for i in range (0,counter5_4):
  total += lead_time_space_weekday5_group4[i]
mean5_4 = total/counter5_4
total = 0
for i in range (0,counter6_1):
  total += lead_time_space_weekday6_group1[i]
mean6_1 = total/counter6_1
total = 0
for i in range (0,counter6_2):
  total += lead_time_space_weekday6_group2[i]
mean6_2 = total/counter6_2
total = 0
for i in range (0,counter6_3):
  total += lead_time_space_weekday6_group3[i]
mean6_3 = total/counter6_3
total = 0
for i in range (0,counter6_4):
  total += lead_time_space_weekday6_group4[i]
mean6_4 = total/counter6_4
total = 0
for i in range (0,counter7_1):
  total += lead_time_space_weekday7_group1[i]
mean7_1 = total/counter7_1
total = 0
for i in range (0,counter7_2):
  total += lead_time_space_weekday7_group2[i]
mean7_2 = total/counter7_2
total = 0
for i in range (0,counter7_3):
  total += lead_time_space_weekday7_group3[i]
mean7_3 = total/counter7_3
total = 0
for i in range (0,counter7_4):
  total += lead_time_space_weekday7_group4[i]
mean7_4 = total/counter7_4

# %%
###宣告標準差
standard1_1 = 0
standard1_2 = 0
standard1_3 = 0
standard1_4 = 0
standard2_1 = 0
standard2_2 = 0
standard2_3 = 0
standard2_4 = 0
standard3_1 = 0
standard3_2 = 0
standard3_3 = 0
standard3_4 = 0
standard4_1 = 0
standard4_2 = 0
standard4_3 = 0
standard4_4 = 0
standard5_1 = 0
standard5_2 = 0
standard5_3 = 0
standard5_4 = 0
standard6_1 = 0
standard6_2 = 0
standard6_3 = 0
standard6_4 = 0
standard7_1 = 0
standard7_2 = 0
standard7_3 = 0
standard7_4 = 0

###standard
variance_total = 0
for i in range(0,counter1_1):
  variance_total += pow( lead_time_space_weekday1_group1[i] - mean1_1,2)
standard1_1 = pow(variance_total/counter1_1,0.5)
variance_total = 0
for i in range(0,counter1_2):
  variance_total += pow( lead_time_space_weekday1_group2[i] - mean1_2,2)
standard1_2 = pow(variance_total/counter1_2,0.5)
variance_total = 0
for i in range(0,counter1_3):
  variance_total += pow( lead_time_space_weekday1_group3[i] - mean1_3,2)
standard1_3 = pow(variance_total/counter1_3,0.5)
variance_total = 0
for i in range(0,counter1_4):
  variance_total += pow( lead_time_space_weekday1_group4[i] - mean1_4,2)
standard1_4 = pow(variance_total/counter1_4,0.5)
variance_total = 0
for i in range(0,counter2_1):
  variance_total += pow( lead_time_space_weekday2_group1[i] - mean2_1,2)
standard2_1 = pow(variance_total/counter2_1,0.5)
variance_total = 0
for i in range(0,counter2_2):
  variance_total += pow( lead_time_space_weekday2_group2[i] - mean2_2,2)
standard2_2 = pow(variance_total/counter2_2,0.5)
variance_total = 0
for i in range(0,counter2_3):
  variance_total += pow( lead_time_space_weekday2_group3[i] - mean2_3,2)
standard2_3 = pow(variance_total/counter2_3,0.5)
variance_total = 0
for i in range(0,counter2_4):
  variance_total += pow( lead_time_space_weekday2_group4[i] - mean2_4,2)
standard2_4 = pow(variance_total/counter2_4,0.5)
variance_total = 0
for i in range(0,counter3_1):
  variance_total += pow( lead_time_space_weekday3_group1[i] - mean3_1,2)
standard3_1 = pow(variance_total/counter3_1,0.5)
variance_total = 0
for i in range(0,counter3_2):
  variance_total += pow( lead_time_space_weekday3_group2[i] - mean3_2,2)
standard3_2 = pow(variance_total/counter3_2,0.5)
variance_total = 0
for i in range(0,counter3_3):
  variance_total += pow( lead_time_space_weekday3_group3[i] - mean3_3,2)
standard3_3 = pow(variance_total/counter3_3,0.5)
variance_total = 0
for i in range(0,counter3_4):
  variance_total += pow( lead_time_space_weekday3_group4[i] - mean3_4,2)
standard3_4 = pow(variance_total/counter3_4,0.5)
variance_total = 0
for i in range(0,counter4_1):
  variance_total += pow( lead_time_space_weekday4_group1[i] - mean4_1,2)
standard4_1 = pow(variance_total/counter4_1,0.5)
variance_total = 0
for i in range(0,counter4_2):
  variance_total += pow( lead_time_space_weekday4_group2[i] - mean4_2,2)
standard4_2 = pow(variance_total/counter4_2,0.5)
variance_total = 0
for i in range(0,counter4_3):
  variance_total += pow( lead_time_space_weekday4_group3[i] - mean4_3,2)
standard4_3 = pow(variance_total/counter4_3,0.5)
variance_total = 0
for i in range(0,counter4_4):
  variance_total += pow( lead_time_space_weekday4_group4[i] - mean4_4,2)
standard4_4 = pow(variance_total/counter4_4,0.5)
variance_total = 0
for i in range(0,counter5_1):
  variance_total += pow( lead_time_space_weekday5_group1[i] - mean5_1,2)
standard5_1 = pow(variance_total/counter5_1,0.5)
variance_total = 0
for i in range(0,counter5_2):
  variance_total += pow( lead_time_space_weekday5_group2[i] - mean5_2,2)
standard5_2 = pow(variance_total/counter5_2,0.5)
variance_total = 0
for i in range(0,counter5_3):
  variance_total += pow( lead_time_space_weekday5_group3[i] - mean5_3,2)
standard5_3 = pow(variance_total/counter5_3,0.5)
variance_total = 0
for i in range(0,counter5_4):
  variance_total += pow( lead_time_space_weekday5_group4[i] - mean5_4,2)
standard5_4 = pow(variance_total/counter5_4,0.5)
variance_total = 0
for i in range(0,counter6_1):
  variance_total += pow( lead_time_space_weekday6_group1[i] - mean6_1,2)
standard6_1 = pow(variance_total/counter6_1,0.5)
variance_total = 0
for i in range(0,counter6_2):
  variance_total += pow( lead_time_space_weekday6_group2[i] - mean6_2,2)
standard6_2 = pow(variance_total/counter6_2,0.5)
variance_total = 0
for i in range(0,counter6_3):
  variance_total += pow( lead_time_space_weekday6_group3[i] - mean6_3,2)
standard6_3 = pow(variance_total/counter6_3,0.5)
variance_total = 0
for i in range(0,counter6_4):
  variance_total += pow( lead_time_space_weekday6_group4[i] - mean6_4,2)
standard6_4 = pow(variance_total/counter6_4,0.5)
variance_total = 0
for i in range(0,counter7_1):
  variance_total += pow( lead_time_space_weekday7_group1[i] - mean7_1,2)
standard7_1 = pow(variance_total/counter7_1,0.5)
variance_total = 0
for i in range(0,counter7_2):
  variance_total += pow( lead_time_space_weekday7_group2[i] - mean7_2,2)
standard7_2 = pow(variance_total/counter7_2,0.5)
variance_total = 0
for i in range(0,counter7_3):
  variance_total += pow( lead_time_space_weekday7_group3[i] - mean7_3,2)
standard7_3 = pow(variance_total/counter7_3,0.5)
variance_total = 0
for i in range(0,counter7_4):
  variance_total += pow( lead_time_space_weekday7_group4[i] - mean7_4,2)
standard7_4 = pow(variance_total/counter7_4,0.5)

# %% [markdown]
# #計算各群常態分配

# %%
###宣告常態分配陣列
distribution1_1 = np.zeros(6)
distribution1_2 = np.zeros(6)
distribution1_3 = np.zeros(6)
distribution1_4 = np.zeros(6)
distribution2_1 = np.zeros(6)
distribution2_2 = np.zeros(6)
distribution2_3 = np.zeros(6)
distribution2_4 = np.zeros(6)
distribution3_1 = np.zeros(6)
distribution3_2 = np.zeros(6)
distribution3_3 = np.zeros(6)
distribution3_4 = np.zeros(6)
distribution4_1 = np.zeros(6)
distribution4_2 = np.zeros(6)
distribution4_3 = np.zeros(6)
distribution4_4 = np.zeros(6)
distribution5_1 = np.zeros(6)
distribution5_2 = np.zeros(6)
distribution5_3 = np.zeros(6)
distribution5_4 = np.zeros(6)
distribution6_1 = np.zeros(6)
distribution6_2 = np.zeros(6)
distribution6_3 = np.zeros(6)
distribution6_4 = np.zeros(6)
distribution7_1 = np.zeros(6)
distribution7_2 = np.zeros(6)
distribution7_3 = np.zeros(6)
distribution7_4 = np.zeros(6)

######宣告函式
def select (x):
  global a,b,c,d,e,f,g
  if(x<=-3):
    a += 1
  elif(x==-2):
    b += 1
  elif(x==-1):
    c += 1
  elif(x==1):
    d += 1
  elif(x==2):
    e += 1
  elif(x>=3):
    f += 1
  elif(x==0):
    g += 1
  distance = 0

######開始計算
###main function
import math
a=b=c=d=e=f=distance =0
for i in range(0, counter1_1):
  distance = (lead_time_space_weekday1_group1[i] - mean1_1)/standard1_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution1_1[0] = round(a/counter1_1*100, 6)
distribution1_1[1] = round(b/counter1_1*100, 6)
distribution1_1[2] = round(c/counter1_1*100, 6)
distribution1_1[3] = round(d/counter1_1*100, 6)
distribution1_1[4] = round(e/counter1_1*100, 6)
distribution1_1[5] = round(f/counter1_1*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter1_2):
  distance = (lead_time_space_weekday1_group2[i] - mean1_2)/standard1_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution1_2[0] = round(a/counter1_2*100, 6)
distribution1_2[1] = round(b/counter1_2*100, 6)
distribution1_2[2] = round(c/counter1_2*100, 6)
distribution1_2[3] = round(d/counter1_2*100, 6)
distribution1_2[4] = round(e/counter1_2*100, 6)
distribution1_2[5] = round(f/counter1_2*100, 6)
  
a=b=c=d=e=f=0
for i in range(0,counter1_3):
  distance = (lead_time_space_weekday1_group3[i] - mean1_3)/standard1_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution1_3[0] = round(a/counter1_3*100, 6)
distribution1_3[1] = round(b/counter1_3*100, 6)
distribution1_3[2] = round(c/counter1_3*100, 6)
distribution1_3[3] = round(d/counter1_3*100, 6)
distribution1_3[4] = round(e/counter1_3*100, 6)
distribution1_3[5] = round(f/counter1_3*100, 6)
  
a=b=c=d=e=f=0
for i in range(0,counter1_4):
  distance = (lead_time_space_weekday1_group4[i] - mean1_4)/standard1_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution1_4[0] = round(a/counter1_4*100, 6)
distribution1_4[1] = round(b/counter1_4*100, 6)
distribution1_4[2] = round(c/counter1_4*100, 6)
distribution1_4[3] = round(d/counter1_4*100, 6)
distribution1_4[4] = round(e/counter1_4*100, 6)
distribution1_4[5] = round(f/counter1_4*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter2_1):
  distance = (lead_time_space_weekday2_group1[i] - mean2_1)/standard2_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution2_1[0] = round(a/counter2_1*100, 6)
distribution2_1[1] = round(b/counter2_1*100, 6)
distribution2_1[2] = round(c/counter2_1*100, 6)
distribution2_1[3] = round(d/counter2_1*100, 6)
distribution2_1[4] = round(e/counter2_1*100, 6)
distribution2_1[5] = round(f/counter2_1*100, 6)
  
a=b=c=d=e=f=0
for i in range(0,counter2_2):
  distance = (lead_time_space_weekday2_group2[i] - mean2_2)/standard2_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution2_2[0] = round(a/counter2_2*100, 6)
distribution2_2[1] = round(b/counter2_2*100, 6)
distribution2_2[2] = round(c/counter2_2*100, 6)
distribution2_2[3] = round(d/counter2_2*100, 6)
distribution2_2[4] = round(e/counter2_2*100, 6)
distribution2_2[5] = round(f/counter2_2*100, 6)
    
a=b=c=d=e=f=0
for i in range(0,counter2_3):
  distance = (lead_time_space_weekday2_group3[i] - mean2_3)/standard2_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution2_3[0] = round(a/counter2_3*100, 6)
distribution2_3[1] = round(b/counter2_3*100, 6)
distribution2_3[2] = round(c/counter2_3*100, 6)
distribution2_3[3] = round(d/counter2_3*100, 6)
distribution2_3[4] = round(e/counter2_3*100, 6)
distribution2_3[5] = round(f/counter2_3*100, 6)
     
a=b=c=d=e=f=0
for i in range(0,counter2_4):
  distance = (lead_time_space_weekday2_group4[i] - mean2_4)/standard2_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution2_4[0] = round(a/counter2_4*100, 6)
distribution2_4[1] = round(b/counter2_4*100, 6)
distribution2_4[2] = round(c/counter2_4*100, 6)
distribution2_4[3] = round(d/counter2_4*100, 6)
distribution2_4[4] = round(e/counter2_4*100, 6)
distribution2_4[5] = round(f/counter2_4*100, 6)
  
a=b=c=d=e=f=0
for i in range(0,counter3_1):
  distance = (lead_time_space_weekday3_group1[i] - mean3_1)/standard3_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution3_1[0] = round(a/counter3_1*100, 6)
distribution3_1[1] = round(b/counter3_1*100, 6)
distribution3_1[2] = round(c/counter3_1*100, 6)
distribution3_1[3] = round(d/counter3_1*100, 6)
distribution3_1[4] = round(e/counter3_1*100, 6)
distribution3_1[5] = round(f/counter3_1*100, 6)
    
a=b=c=d=e=f=0
for i in range(0,counter3_2):
  distance = (lead_time_space_weekday3_group2[i] - mean3_2)/standard3_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution3_2[0] = round(a/counter3_2*100, 6)
distribution3_2[1] = round(b/counter3_2*100, 6)
distribution3_2[2] = round(c/counter3_2*100, 6)
distribution3_2[3] = round(d/counter3_2*100, 6)
distribution3_2[4] = round(e/counter3_2*100, 6)
distribution3_2[5] = round(f/counter3_2*100, 6)
    
a=b=c=d=e=f=0
for i in range(0,counter3_3):
  distance = (lead_time_space_weekday3_group3[i] - mean3_3)/standard3_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution3_3[0] = round(a/counter3_3*100, 6)
distribution3_3[1] = round(b/counter3_3*100, 6)
distribution3_3[2] = round(c/counter3_3*100, 6)
distribution3_3[3] = round(d/counter3_3*100, 6)
distribution3_3[4] = round(e/counter3_3*100, 6)
distribution3_3[5] = round(f/counter3_3*100, 6)
  
a=b=c=d=e=f=0
for i in range(0,counter3_4):
  distance = (lead_time_space_weekday3_group4[i] - mean3_4)/standard3_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution3_4[0] = round(a/counter3_4*100, 6)
distribution3_4[1] = round(b/counter3_4*100, 6)
distribution3_4[2] = round(c/counter3_4*100, 6)
distribution3_4[3] = round(d/counter3_4*100, 6)
distribution3_4[4] = round(e/counter3_4*100, 6)
distribution3_4[5] = round(f/counter3_4*100, 6)
    
a=b=c=d=e=f=0
for i in range(0,counter4_1):
  distance = (lead_time_space_weekday4_group1[i] - mean4_1)/standard4_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution4_1[0] = round(a/counter4_1*100, 6)
distribution4_1[1] = round(b/counter4_1*100, 6)
distribution4_1[2] = round(c/counter4_1*100, 6)
distribution4_1[3] = round(d/counter4_1*100, 6)
distribution4_1[4] = round(e/counter4_1*100, 6)
distribution4_1[5] = round(f/counter4_1*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter4_2):
  distance = (lead_time_space_weekday4_group2[i] - mean4_2)/standard4_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution4_2[0] = round(a/counter4_2*100, 6)
distribution4_2[1] = round(b/counter4_2*100, 6)
distribution4_2[2] = round(c/counter4_2*100, 6)
distribution4_2[3] = round(d/counter4_2*100, 6)
distribution4_2[4] = round(e/counter4_2*100, 6)
distribution4_2[5] = round(f/counter4_2*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter4_3):
  distance = (lead_time_space_weekday4_group3[i] - mean4_3)/standard4_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution4_3[0] = round(a/counter4_3*100, 6)
distribution4_3[1] = round(b/counter4_3*100, 6)
distribution4_3[2] = round(c/counter4_3*100, 6)
distribution4_3[3] = round(d/counter4_3*100, 6)
distribution4_3[4] = round(e/counter4_3*100, 6)
distribution4_3[5] = round(f/counter4_3*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter4_4):
  distance = (lead_time_space_weekday4_group4[i] - mean4_4)/standard4_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution4_4[0] = round(a/counter4_4*100, 6)
distribution4_4[1] = round(b/counter4_4*100, 6)
distribution4_4[2] = round(c/counter4_4*100, 6)
distribution4_4[3] = round(d/counter4_4*100, 6)
distribution4_4[4] = round(e/counter4_4*100, 6)
distribution4_4[5] = round(f/counter4_4*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter5_1):
  distance = (lead_time_space_weekday5_group1[i] - mean5_1)/standard5_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution5_1[0] = round(a/counter5_1*100, 6)
distribution5_1[1] = round(b/counter5_1*100, 6)
distribution5_1[2] = round(c/counter5_1*100, 6)
distribution5_1[3] = round(d/counter5_1*100, 6)
distribution5_1[4] = round(e/counter5_1*100, 6)
distribution5_1[5] = round(f/counter5_1*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter5_2):
  distance = (lead_time_space_weekday5_group2[i] - mean5_2)/standard5_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution5_2[0] = round(a/counter5_2*100, 6)
distribution5_2[1] = round(b/counter5_2*100, 6)
distribution5_2[2] = round(c/counter5_2*100, 6)
distribution5_2[3] = round(d/counter5_2*100, 6)
distribution5_2[4] = round(e/counter5_2*100, 6)
distribution5_2[5] = round(f/counter5_2*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter5_3):
  distance = (lead_time_space_weekday5_group3[i] - mean5_3)/standard5_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution5_3[0] = round(a/counter5_3*100, 6)
distribution5_3[1] = round(b/counter5_3*100, 6)
distribution5_3[2] = round(c/counter5_3*100, 6)
distribution5_3[3] = round(d/counter5_3*100, 6)
distribution5_3[4] = round(e/counter5_3*100, 6)
distribution5_3[5] = round(f/counter5_3*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter5_4):
  distance = (lead_time_space_weekday5_group4[i] - mean5_4)/standard5_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution5_4[0] = round(a/counter5_4*100, 6)
distribution5_4[1] = round(b/counter5_4*100, 6)
distribution5_4[2] = round(c/counter5_4*100, 6)
distribution5_4[3] = round(d/counter5_4*100, 6)
distribution5_4[4] = round(e/counter5_4*100, 6)
distribution5_4[5] = round(f/counter5_4*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter6_1):
  distance = (lead_time_space_weekday6_group1[i] - mean6_1)/standard6_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution6_1[0] = round(a/counter6_1*100, 6)
distribution6_1[1] = round(b/counter6_1*100, 6)
distribution6_1[2] = round(c/counter6_1*100, 6)
distribution6_1[3] = round(d/counter6_1*100, 6)
distribution6_1[4] = round(e/counter6_1*100, 6)
distribution6_1[5] = round(f/counter6_1*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter6_2):
  distance = (lead_time_space_weekday6_group2[i] - mean6_2)/standard6_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution6_2[0] = round(a/counter6_2*100, 6)
distribution6_2[1] = round(b/counter6_2*100, 6)
distribution6_2[2] = round(c/counter6_2*100, 6)
distribution6_2[3] = round(d/counter6_2*100, 6)
distribution6_2[4] = round(e/counter6_2*100, 6)
distribution6_2[5] = round(f/counter6_2*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter6_3):
  distance = (lead_time_space_weekday6_group3[i] - mean6_3)/standard6_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution6_3[0] = round(a/counter6_3*100, 6)
distribution6_3[1] = round(b/counter6_3*100, 6)
distribution6_3[2] = round(c/counter6_3*100, 6)
distribution6_3[3] = round(d/counter6_3*100, 6)
distribution6_3[4] = round(e/counter6_3*100, 6)
distribution6_3[5] = round(f/counter6_3*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter6_4):
  distance = (lead_time_space_weekday6_group4[i] - mean6_4)/standard6_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution6_4[0] = round(a/counter6_4*100, 6)
distribution6_4[1] = round(b/counter6_4*100, 6)
distribution6_4[2] = round(c/counter6_4*100, 6)
distribution6_4[3] = round(d/counter6_4*100, 6)
distribution6_4[4] = round(e/counter6_4*100, 6)
distribution6_4[5] = round(f/counter6_4*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter7_1):
  distance = (lead_time_space_weekday7_group1[i] - mean7_1)/standard7_1
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution7_1[0] = round(a/counter7_1*100, 6)
distribution7_1[1] = round(b/counter7_1*100, 6)
distribution7_1[2] = round(c/counter7_1*100, 6)
distribution7_1[3] = round(d/counter7_1*100, 6)
distribution7_1[4] = round(e/counter7_1*100, 6)
distribution7_1[5] = round(f/counter7_1*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter7_2):
  distance = (lead_time_space_weekday7_group2[i] - mean7_2)/standard7_2
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution7_2[0] = round(a/counter7_2*100, 6)
distribution7_2[1] = round(b/counter7_2*100, 6)
distribution7_2[2] = round(c/counter7_2*100, 6)
distribution7_2[3] = round(d/counter7_2*100, 6)
distribution7_2[4] = round(e/counter7_2*100, 6)
distribution7_2[5] = round(f/counter7_2*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter7_3):
  distance = (lead_time_space_weekday7_group3[i] - mean7_3)/standard7_3
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution7_3[0] = round(a/counter7_3*100, 6)
distribution7_3[1] = round(b/counter7_3*100, 6)
distribution7_3[2] = round(c/counter7_3*100, 6)
distribution7_3[3] = round(d/counter7_3*100, 6)
distribution7_3[4] = round(e/counter7_3*100, 6)
distribution7_3[5] = round(f/counter7_3*100, 6)

a=b=c=d=e=f=0
for i in range(0,counter7_4):
  distance = (lead_time_space_weekday7_group4[i] - mean7_4)/standard7_4
  if(distance>0):
    select(math.ceil(distance))
  elif(distance<0):
    select(math.floor(distance)) 
distribution7_4[0] = round(a/counter7_4*100, 6)
distribution7_4[1] = round(b/counter7_4*100, 6)
distribution7_4[2] = round(c/counter7_4*100, 6)
distribution7_4[3] = round(d/counter7_4*100, 6)
distribution7_4[4] = round(e/counter7_4*100, 6)
distribution7_4[5] = round(f/counter7_4*100, 6)

# %%
print('分配表如下:分別為(-3以下,-2,-1,1,2,3以上)個標準差內')
print('weekday1_group1的分配:',distribution1_1)
print('weekday1_group2的分配:',distribution1_2)
print('weekday1_group3的分配:',distribution1_3)
print('weekday1_group4的分配:',distribution1_4)
print('weekday2_group1的分配:',distribution2_1)
print('weekday2_group2的分配:',distribution2_2)
print('weekday2_group3的分配:',distribution2_3)
print('weekday2_group4的分配:',distribution2_4)
print('weekday3_group1的分配:',distribution3_1)
print('weekday3_group2的分配:',distribution3_2)
print('weekday3_group3的分配:',distribution3_3)
print('weekday3_group4的分配:',distribution3_4)
print('weekday4_group1的分配:',distribution4_1)
print('weekday4_group2的分配:',distribution4_2)
print('weekday4_group3的分配:',distribution4_3)
print('weekday4_group4的分配:',distribution4_4)
print('weekday5_group1的分配:',distribution5_1)
print('weekday5_group2的分配:',distribution5_2)
print('weekday5_group3的分配:',distribution5_3)
print('weekday5_group4的分配:',distribution5_4)
print('weekday6_group1的分配:',distribution6_1)
print('weekday6_group2的分配:',distribution6_2)
print('weekday6_group3的分配:',distribution6_3)
print('weekday6_group4的分配:',distribution6_4)
print('weekday7_group1的分配:',distribution7_1)
print('weekday7_group2的分配:',distribution7_2)
print('weekday7_group3的分配:',distribution7_3)
print('weekday7_group4的分配:',distribution7_4)
# Out:
# 分配表如下:分別為(-3以下,-2,-1,1,2,3以上)個標準差內
# weekday1_group1的分配: [ 0.        0.       72.390572 17.027417  6.445406  4.136604]
# weekday1_group2的分配: [ 0.        0.       74.330596 17.029632  5.676544  2.963227]
# weekday1_group3的分配: [ 0.        0.       74.796748 16.235526  5.59251   3.375216]
# weekday1_group4的分配: [ 0.        0.       71.224003 17.030344  6.699625  5.046028]
# weekday2_group1的分配: [ 0.        0.       68.867925 18.949959  7.793273  4.388843]
# weekday2_group2的分配: [ 0.        0.       72.284295 16.170081  6.952204  4.59342 ]
# weekday2_group3的分配: [ 0.        0.       75.436681 16.768559  3.864629  3.930131]
# weekday2_group4的分配: [ 0.        0.       71.541734 16.781575  6.821182  4.855508]
# weekday3_group1的分配: [ 0.        0.       71.777778 16.088889  7.066667  5.066667]
# weekday3_group2的分配: [ 0.        0.       74.829268 14.536585  5.203252  5.430894]
# weekday3_group3的分配: [ 0.        0.       76.193467 13.735343  4.522613  5.548576]
# ...
