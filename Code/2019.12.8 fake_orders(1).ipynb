# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd drive/My\ Drive/
# Out:
# [Errno 2] No such file or directory: 'drive/My Drive/'
# /content/drive/My Drive/case:小樹屋/編輯資料

# %%
ls
# Out:
#  12.05/                       'Fake Orders empty time.csv'   spaces_fix.csv
# 'database variable(all).csv'   new_data.csv                  spaces_times.csv
# 'Fake Orders.csv'              new_space.csv

# %%
cd 編輯資料/
# Out:
# [Errno 2] No such file or directory: '編輯資料/'
# /content/drive/My Drive/case:小樹屋/編輯資料

# %%
import numpy as np
import pandas as pd
import csv

# %%
order = pd.read_csv('database variable(all).csv',encoding='big5')
order
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (21,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#             id  space_id  people  ...  sort        lat         lng
# 0         9615         1      17  ...     0  25.046006  121.519176
# 1         9617         1      17  ...     0  25.046006  121.519176
# 2         9618         1      17  ...     0  25.046006  121.519176
# 3         9616         1      17  ...     0  25.046006  121.519176
# 4         9622         1      17  ...     0  25.046006  121.519176
# ...        ...       ...     ...  ...   ...        ...         ...
# 135996  183557       110       6  ...    69  25.033409  121.531367
# 135997  185778         3       6  ...    84  25.035915  121.547860
# 135998  178636        74      10  ...    82  25.051274  121.563282
# ...

# %%
with open('Fake Orders.csv', mode='w', newline='') as f:
    FOrders_writer = csv.writer(f)
    order_id = 1

    FOrders_writer.writerow(['id', 'space_id', 'size', 'hours', 'price', 'order_price', 'price_per_size', 'date', 'start', 'end', 'zipcode', 'category'])
    for i in range(0, len(order['space_id'])):
     FOrders_writer.writerow([order_id, 'space_id', 'size', 'hours', 'price', 'order_price', 'price_per_size', 'date', 'start', 'end', 'zipcode', 'category'])
     order_id += 1

# %% [markdown]
# #Fake Data Main
# 三個井字號###代表尚未完成的程式碼 , --- 為尚須修改部分

# %%
#製作假訂單表格
with open('Fake Orders.csv', mode='w', newline='') as f:
    FOrders_writer = csv.writer(f)
    order_id = 1

    FOrders_writer.writerow(['id', 'space_id', 'size', 'hours', 'price', 'order_price', 'price_per_size', 'date', 'start', 'end', 'zipcode', 'category'])

  

#填入假訂單data
for i in range(0,100): #測試階段先掃描日期0到100
  while (i ==order['date'])
    for j in range(0,100): #掃描每日訂單 space_id 先0~100
      if(j==order['space_id']): #掃描到有訂單,---目前有訂單space_id重複的問題
        start_signal =1 #紀錄假訂單的起始時間
        for k in range(1,24): #掃描1天24小時 , ---目前時間尚未格式化
          if(k == order['start']):
          fake_start = start_signal; #fake_data 起始時間
          fake_end = k;  #fake_data 結束時間
            ###將此時段寫入假訂單
          start_signal = order['end'];
          k = order['end']; # k直接跳到下一個時間段,不用一個一個慢慢掃描
          if(fake_start == fake_end):
            ###不紀錄

        else #沒掃描到訂單=當天無訂單
          ###紀錄一整天為fake data
